# %% [markdown]
# # Visualisation des données

# %% [markdown]
# ### Imports et données

# %% [markdown]
# #### Imports, dates et valeurs de Alpha α

# %%
# Import seaborn et matplotlib
import seaborn as sns # cette librairie fait des meilleurs graphiques que Matplotlib (elle le complèmente)
import matplotlib.pyplot as plt # librairie pour les graphiques
sns.set_theme() # thème de défault de Seaborn

# %%
# Dates de prises de mesures (à modifier avec chaque prise de mesure)
dates = ["23-10-2023", "06-11-2023", "08-11-2023", "10-11-2023", "14-11-2023", "20-11-2023", "24-11-2023", "30-11-2023"]

# Valeurs de Alpha α
alpha_values = [0.63, 0.57, 1.03, 0.62, 0.29, 0.44, 0.53, 0.20] # données non-modifiées 

# Taille des particules
particle_size = ["coarse", "coarse", "fine and coarse", "coarse", "coarse", "coarse", "coarse", "coarse"]

# %% [markdown]
# #### Données de Rayan

# %% [markdown]
# Le protocole de la prise de mesures est le suivant:
# - [TO-DO]
# -
# -
# -
#
# Les données de Rayan sont contenues dans une liste dont les valeurs correspondent au taux de bons tirs dans le panier de basketball pendant tous le temps des prises de mesures. Par exemple, la première mesure de la liste correspond au jour 1, la deuxième au jour 2...etc. (à vérifier la liste des jours des prises de mesures).

# %%
# Valeurs de Rayan (le taux des bons tirs de basket de Rayan)
# Chaque valeur correspond à une journée dans la liste
# Attention!!! Les valeurs doivent être vérifiées et comparées aux valeurs du cahier de bord 

athlete_results_rayan = [0.6, 0.1, 0.4, 0.5, 0.4, 0.4, 0.6, 0.5] # données non-modifiées (et bien documentées!)
# Note: à comparer aux hypothèses posées dans les notes de chaque jour de prise de mesure (e.g. raisons de fatigue)

# %%
# Vérifier que les listes sont de la même longueur pour continuer (Rayan)
print("len(dates) = ", len(dates))
print("len(athlete_results_rayan) = ", len(athlete_results_rayan))
print("len(alpha_values) = ", len(alpha_values))
print("len(particle_size) = ", len(particle_size))
# Out:
# len(dates) =  8
# len(athlete_results_rayan) =  8
# len(alpha_values) =  8
# len(particle_size) =  8

# %% [markdown]
# #### Données de Yara

# %% [markdown]
# Le protocole de la prise de mesures des données de Yara est le suivant:
# - On mesure le BPM de Yara au repos
# - Elle effectue 15 secondes de l'activité physique: les jumping jacks
# - On mesure son BPM après les 15 secondes d'activité
# - Elle se repose 15 secondes
# - Elle effectue 30 secondes de l'activité physique: les jumping jacks
# - On mesure son BPM après les 30 secondes d'activité
# - Elle se repose 30 secondes
# - Elle effectue 60 secondes, soit une minute, de l'activité physique: les jumping jacks
# - On mesure son BPM après les 60 secondes d'activité
# - Elle se repose 60 secondes
#
# Les données de Yara sont contenues dans des listes dont chacune correspond aux mesures de BPM pendant tous le temps des prises de mesures. Par exemple, la première mesure d'une liste correspond au jour 1, la deuxième au jour 2...etc. (à vérifier la liste des jours des prises de mesures).

# %%
# Valeurs de Yara (chaque type de BPM)
# Chaque valeur correspond à une journée dans la liste
# Attention!!! Les valeurs doivent être vérifiées et comparées aux valeurs du cahier de bord 

athlete_results_yara_restingBPM        = [ 90,  89,  90,  82,  91, 101,  97, 100] # données modifiées 

athlete_results_yara_after15s_exercise = [135, 120, 125, 120, 132, 143, 132, 128] # données modifiées 
athlete_results_yara_after15s_rest     = [126, 105, 109, 105, 121, 124, 119, 115] # données modifiées 

athlete_results_yara_after30s_exercise = [173, 167, 167, 162, 171, 169, 160, 165] # données modifiées 
athlete_results_yara_after30s_rest     = [154, 158, 139, 133, 140, 141, 134, 145] # données modifiées 

athlete_results_yara_after60s_exercise = [167, 170, 137, 147, 172, 142, 141, 153] # données modifiées 
athlete_results_yara_after60s_rest     = [123, 110, 107, 120, 144, 125, 122, 130] # données modifiées

# %%
# Vérifier que les listes sont de la même longueur pour continuer (Yara)
print("len(dates) = ", len(dates))

print("len(athlete_results_yara_restingBPM) = ",        len(athlete_results_yara_restingBPM))

print("len(athlete_results_yara_after15s_exercise) = ", len(athlete_results_yara_after15s_exercise))
print("len(athlete_results_yara_after15s_rest) = ",     len(athlete_results_yara_after15s_rest))

print("len(athlete_results_yara_after30s_exercise) = ", len(athlete_results_yara_after30s_exercise))
print("len(athlete_results_yara_after30s_rest) = ",     len(athlete_results_yara_after30s_rest))

print("len(athlete_results_yara_after60s_exercise) = ", len(athlete_results_yara_after60s_exercise))
print("len(athlete_results_yara_after60s_rest) = ",     len(athlete_results_yara_after60s_rest))

print("len(alpha_values) = ", len(alpha_values))
print("len(particle_size) = ", len(particle_size))
# Out:
# len(dates) =  8
# len(athlete_results_yara_restingBPM) =  8
# len(athlete_results_yara_after15s_exercise) =  8
# len(athlete_results_yara_after15s_rest) =  8
# len(athlete_results_yara_after30s_exercise) =  8
# len(athlete_results_yara_after30s_rest) =  8
# len(athlete_results_yara_after60s_exercise) =  8
# len(athlete_results_yara_after60s_rest) =  8
# len(alpha_values) =  8
# len(particle_size) =  8

# %%
# Différences entre BPM après 60s d'exercices et 60 secondes de repos de Yara
differences_yara = []

for i in range(len(athlete_results_yara_after60s_exercise)):
    difference_yara = athlete_results_yara_after60s_exercise[i] - athlete_results_yara_after60s_rest[i]
    differences_yara.append(difference_yara)

# %% [markdown]
# #### Données de Aya

# %% [markdown]
# Le protocole de la prise de mesures des données de Aya est le suivant:
# - On mesure le BPM de Aya au repos
# - Elle effectue 15 secondes de l'activité physique: la planck
# - On mesure son BPM après les 15 secondes d'activité
# - Elle se repose 15 secondes
# - Elle effectue 30 secondes de l'activité physique: la planck
# - On mesure son BPM après les 30 secondes d'activité
# - Elle se repose 30 secondes
# - Elle effectue 60 secondes, soit une minute, de l'activité physique: la planck
# - On mesure son BPM après les 60 secondes d'activité
# - Elle se repose 60 secondes
#
# Les données de Aya sont contenues dans des listes dont chacune correspond aux mesures de BPM pendant tous le temps des prises de mesures. Par exemple, la première mesure d'une liste correspond au jour 1, la deuxième au jour 2...etc. (à vérifier la liste des jours des prises de mesures).

# %%
# Valeurs de Aya (chaque type de BPM)
# Chaque valeur correspond à une journée dans la liste
# Attention!!! Les valeurs doivent être vérifiées et comparées aux valeurs du cahier de bord 

athlete_results_aya_restingBPM        = [ 71,  72,  96,  98,  81,  63,  98,  82] # données modifiées 

athlete_results_aya_after15s_exercise = [103, 125, 130, 137, 124, 107, 131, 128] # données modifiées 
athlete_results_aya_after15s_rest     = [ 85, 111, 119, 126, 109, 101, 117, 104] # données modifiées 

athlete_results_aya_after30s_exercise = [129, 120, 127,  98,  94, 125, 132, 125] # données modifiées 
athlete_results_aya_after30s_rest     = [105, 103, 108,  77,  60, 107, 101, 103] # données modifiées 

athlete_results_aya_after60s_exercise = [141, 106, 132, 114, 106, 142, 134, 123] # données modifiées 
athlete_results_aya_after60s_rest     = [116,  79, 112,  88,  93, 113, 103,  95] # données modifiées

# %%
# Vérifier que les listes sont de la même longueur pour continuer (Aya)
print("len(dates) = ", len(dates))

print("len(athlete_results_aya_restingBPM) = ",        len(athlete_results_aya_restingBPM))

print("len(athlete_results_aya_after15s_exercise) = ", len(athlete_results_aya_after15s_exercise))
print("len(athlete_results_aya_after15s_rest) = ",     len(athlete_results_aya_after15s_rest))

print("len(athlete_results_aya_after30s_exercise) = ", len(athlete_results_aya_after30s_exercise))
print("len(athlete_results_aya_after30s_rest) = ",     len(athlete_results_aya_after30s_rest))

print("len(athlete_results_aya_after60s_exercise) = ", len(athlete_results_aya_after60s_exercise))
print("len(athlete_results_aya_after60s_rest) = ",     len(athlete_results_aya_after60s_rest))

print("len(alpha_values) = ", len(alpha_values))
print("len(particle_size) = ", len(particle_size))
# Out:
# len(dates) =  8
# len(athlete_results_aya_restingBPM) =  8
# len(athlete_results_aya_after15s_exercise) =  8
# len(athlete_results_aya_after15s_rest) =  8
# len(athlete_results_aya_after30s_exercise) =  8
# len(athlete_results_aya_after30s_rest) =  8
# len(athlete_results_aya_after60s_exercise) =  8
# len(athlete_results_aya_after60s_rest) =  8
# len(alpha_values) =  8
# len(particle_size) =  8

# %%
# Différences entre BPM après 60s d'exercices et 60 secondes de repos de Yara
differences_aya = []

for i in range(len(athlete_results_aya_after60s_exercise)):
    difference_aya = athlete_results_aya_after60s_exercise[i] - athlete_results_aya_after60s_rest[i]
    differences_aya.append(difference_aya)

# %%
# Créer les "labels" de l'axe des abscisses (pour les graphiques)
x_labels = ["BPM de Repos", 
            "Après 15s d'Activité", "Après 15s de Repos",
            "Après 30s d'Activité", "Après 30s de Repos", 
            "Après 60s d'Activité", "Après 60s de Repos"]

# %% [markdown]
# ### Rayan: Résultats liées au Basketball (résultats en fonction des jours)

# %%
# Visualiser les performances de Rayan en fonction des jours avec un graphique
# Rayan est positionné à 5 pas d'un panier de basketball. 
# Il doit effectuer 10 tirs, d'où vient sa performance (la quantité de bons tirs sur les 10 tirs)

sns.set(font_scale=1.2, font="Verdana")

plt.figure(figsize=(10, 6))
sns.lineplot(x=dates, y=athlete_results_rayan)

plt.xlabel("Dates de l'activité physique", fontweight="bold", fontsize=10)
plt.ylabel("Performance de Rayan (taux de bons tirs)", fontweight="bold", fontsize=10)

plt.title("Variation des performances de Rayan en fonction des jours", fontweight="bold", fontsize=14)

plt.xticks(rotation=45)
plt.show()

# %%
# Visualiser les valeurs de Alpha α en fonction des jours avec un graphique
plt.figure(figsize=(10, 6))
sns.lineplot(x=dates, y=alpha_values)

plt.xlabel("Dates de l'activité physique", fontweight="bold")
plt.ylabel("Valeurs de Alpha α", fontweight="bold")

plt.title("Variation des valeurs de Alpha α en fonction des jours", fontweight="bold", fontsize=14)

plt.xticks(rotation=45)
plt.show()

# %%
# Graphique Commun 
sns.set(font_scale=1.05, font="Verdana")

plt.figure(figsize=(10, 6))

# Plotting Rayan's performance
rayan_line = sns.lineplot(
    x=dates, 
    y=athlete_results_rayan, 
    label="Performances de Rayan",
    style=True,
    dashes=[(2, 2)],
    legend=False
)

# Plotting Alpha values
alpha_plot = sns.lineplot(
    x=dates, 
    y=alpha_values, 
    label="Valeurs de Alpha α",
    style=True,
    dashes=[(2, 2)],
    legend=False
)

plt.xlabel("Dates de l'activité physique", fontweight="bold")
plt.ylabel("Performances de Rayan", fontweight="bold")

plt.title("Variation des performances de Rayan et des valeurs de Alpha α en fonction des jours", fontweight="bold", fontsize=14)

# Adding titles to each point on the Alpha graph
for i in range(len(dates)):
    alpha_plot.text(dates[i], alpha_values[i], particle_size[i], horizontalalignment='left', size='medium', color='black')

plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# ### Yara: Résultats liées aux Jumping Jacks (résultats en fonction des jours)

# %%
sns.set(font_scale=1.2, font="Verdana")

plt.figure(figsize=(16, 32))
for i in range(8): # 8 parce que il y a 8 données
    plt.subplot(8, 1, i + 1)
    sns.lineplot(x=x_labels, y=[athlete_results_yara_restingBPM[i],
                                athlete_results_yara_after15s_exercise[i],
                                athlete_results_yara_after15s_rest[i],
                                athlete_results_yara_after30s_exercise[i],
                                athlete_results_yara_after30s_rest[i],
                                athlete_results_yara_after60s_exercise[i],
                                athlete_results_yara_after60s_rest[i]])
    plt.title(f"BPM Yara: {dates[i]} (α = {alpha_values[i]}, {particle_size[i]})", fontweight="bold", fontsize=23)
    plt.ylabel("BPM de Yara", fontweight="bold", fontsize=15)
plt.tight_layout()
plt.show()

# %%
# Graphique Commun 
sns.set_theme(font_scale=1.12, font="Verdana")
fig, ax1 = plt.subplots(figsize=(12, 8))

# Créer le second axe
ax2 = ax1.twinx()

# Graphique des Performances de Yara (pour le premier graphique des y)
yara_line = sns.lineplot(
    x=dates, y=differences_yara,
    ax=ax1, style=True, 
    color='b', dashes=[(2, 2)],
    label="Performance de Yara (BPM)", legend=False
)
yara_line.legend(loc="upper right")

# Graphique des valeurs de Alpha (pour le deuxième graphique des y)
alpha_line = sns.lineplot(
    x=dates, y=alpha_values,
    ax=ax2, style=True, 
    color='r', dashes=[(2, 2)],
    label="Valeurs de Alpha α", legend=False
)
alpha_line.legend(loc="upper left")

# Tailles des particules
for i in range(len(dates)):
    ax2.text(dates[i], alpha_values[i], particle_size[i], horizontalalignment='left', size='small', color='black')

# Les labels
ax1.set_xlabel("Dates de l'activité physique", fontweight="bold")
ax1.set_ylabel("Performance de Yara (BPM)", fontweight="bold")
ax2.set_ylabel("Valeurs de Alpha α", fontweight="bold")

# Le titre du graphique
plt.title("Variation des performances de Yara & des valeurs de Alpha α en fonction des jours", fontweight="bold", fontsize=14)

# Rotation de l'axe des x
plt.xticks(rotation=45)

# Combiner les légendes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right')

plt.show()

# %% [markdown]
# ### Aya: Résultats liées au Planck (résultats en fonction des jours)

# %%
sns.set(font_scale=1.2, font="Verdana")

plt.figure(figsize=(16, 32))
for i in range(8): # 8 parce que il y a 8 données
    plt.subplot(8, 1, i + 1)
    sns.lineplot(x=x_labels, y=[athlete_results_aya_restingBPM[i],
                                athlete_results_aya_after15s_exercise[i],
                                athlete_results_aya_after15s_rest[i],
                                athlete_results_aya_after30s_exercise[i],
                                athlete_results_aya_after30s_rest[i],
                                athlete_results_aya_after60s_exercise[i],
                                athlete_results_aya_after60s_rest[i]])
    plt.title(f"BPM Aya: {dates[i]} (α = {alpha_values[i]}, {particle_size[i]})", fontweight="bold", fontsize=23)
    plt.ylabel("BPM de Aya", fontweight="bold", fontsize=15)
plt.tight_layout()
plt.show()

# %%
# Graphique Commun 
sns.set_theme(font_scale=1.12, font="Verdana")
fig, ax1 = plt.subplots(figsize=(12, 8))

# Créer le second axe
ax2 = ax1.twinx()

# Graphique des Performances de Aya (pour le premier graphique des y)
aya_line = sns.lineplot(
    x=dates, y=differences_aya,
    ax=ax1, style=True, 
    color='b', dashes=[(2, 2)],
    label="Performance de Aya (BPM)", legend=False
)
yara_line.legend(loc="upper right")

# Graphique des valeurs de Alpha (pour le deuxième graphique des y)
alpha_line = sns.lineplot(
    x=dates, y=alpha_values,
    ax=ax2, style=True, 
    color='r', dashes=[(2, 2)],
    label="Valeurs de Alpha α", legend=False
)
alpha_line.legend(loc="upper left")

# Tailles des particules
for i in range(len(dates)):
    ax2.text(dates[i], alpha_values[i], particle_size[i], horizontalalignment='left', size='small', color='black')

# Les labels
ax1.set_xlabel("Dates de l'activité physique", fontweight="bold")
ax1.set_ylabel("Performance de Aya (BPM)", fontweight="bold")
ax2.set_ylabel("Valeurs de Alpha α", fontweight="bold")

# Le titre du graphique
plt.title("Variation des performances de Aya & des valeurs de Alpha α en fonction des jours", fontweight="bold", fontsize=14)

# Rotation de l'axe des x
plt.xticks(rotation=45)

# Combiner les légendes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

plt.show()
